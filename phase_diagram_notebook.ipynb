# %%
import pandas as pd
from pyTNG.cosmology import TNGcosmo
from pyTNG import data_interface as _data_interface
import os
import illustris_python as il
from scipy.stats import binned_statistic_2d

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from phase_diagram import *

# %%
params = {'nx':45}
generate_histogram_plot(6, 4779, params)
# Out:
# /freya/u/ivkos/analysis/phase_diagram.py:187: RuntimeWarning: divide by zero encountered in log10
#   subfig = ax.pcolormesh(

# %%
import crashpy
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-32-d948fd71bf54> in <module>
# ----> 1 import crashpy
#
# ModuleNotFoundError: No module named 'crashpy'

# %%
generate_histogram_plot(8, 10)
# Out:
# /freya/u/ivkos/analysis/phase_diagram.py:188: RuntimeWarning: divide by zero encountered in log10
#   )

# %%
generate_histogram_plot(8, 2606)

# %%
generate_histogram_plot(10, 519)
